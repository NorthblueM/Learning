# %% [markdown]
# <h1>chapter2-索引 Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#第二章-索引" data-toc-modified-id="第二章-索引-1">第二章 索引</a></span></li><li><span><a href="#一、单级索引" data-toc-modified-id="一、单级索引-2">一、单级索引</a></span><ul class="toc-item"><li><span><a href="#1.1-loc方法、iloc方法、[]操作符" data-toc-modified-id="1.1-loc方法、iloc方法、[]操作符-2.1">1.1 loc方法、iloc方法、[]操作符</a></span><ul class="toc-item"><li><span><a href="#1.1.1-loc方法" data-toc-modified-id="1.1.1-loc方法-2.1.1">1.1.1 loc方法</a></span><ul class="toc-item"><li><span><a href="#1.1.1.1-单行索引" data-toc-modified-id="1.1.1.1-单行索引-2.1.1.1">1.1.1.1 单行索引</a></span></li><li><span><a href="#1.1.1.2-多行索引" data-toc-modified-id="1.1.1.2-多行索引-2.1.1.2">1.1.1.2 多行索引</a></span></li><li><span><a href="#1.1.1.3-单列索引" data-toc-modified-id="1.1.1.3-单列索引-2.1.1.3">1.1.1.3 单列索引</a></span></li><li><span><a href="#1.1.1.4-多列索引" data-toc-modified-id="1.1.1.4-多列索引-2.1.1.4">1.1.1.4 多列索引</a></span></li><li><span><a href="#1.1.1.5-联合索引" data-toc-modified-id="1.1.1.5-联合索引-2.1.1.5">1.1.1.5 联合索引</a></span></li><li><span><a href="#1.1.1.6-函数式索引" data-toc-modified-id="1.1.1.6-函数式索引-2.1.1.6">1.1.1.6 函数式索引</a></span></li><li><span><a href="#1.1.1.7-布尔索引（将重点在第2节介绍）" data-toc-modified-id="1.1.1.7-布尔索引（将重点在第2节介绍）-2.1.1.7">1.1.1.7 布尔索引（将重点在第2节介绍）</a></span></li></ul></li><li><span><a href="#1.1.2-iloc方法（注意与loc不同，切片右端点不包含，索引从0开始）" data-toc-modified-id="1.1.2-iloc方法（注意与loc不同，切片右端点不包含，索引从0开始）-2.1.2">1.1.2 iloc方法（注意与loc不同，切片右端点不包含，索引从0开始）</a></span><ul class="toc-item"><li><span><a href="#1.1.2.1-单行索引" data-toc-modified-id="1.1.2.1-单行索引-2.1.2.1">1.1.2.1 单行索引</a></span></li><li><span><a href="#1.1.2.2-多行索引" data-toc-modified-id="1.1.2.2-多行索引-2.1.2.2">1.1.2.2 多行索引</a></span></li><li><span><a href="#1.1.2.3-单列索引" data-toc-modified-id="1.1.2.3-单列索引-2.1.2.3">1.1.2.3 单列索引</a></span></li><li><span><a href="#1.1.2.4-多列索引" data-toc-modified-id="1.1.2.4-多列索引-2.1.2.4">1.1.2.4 多列索引</a></span></li><li><span><a href="#1.1.2.5-混合索引" data-toc-modified-id="1.1.2.5-混合索引-2.1.2.5">1.1.2.5 混合索引</a></span></li><li><span><a href="#1.1.2.6-函数式索引" data-toc-modified-id="1.1.2.6-函数式索引-2.1.2.6">1.1.2.6 函数式索引</a></span></li></ul></li><li><span><a href="#1.1.3-[]操作符" data-toc-modified-id="1.1.3-[]操作符-2.1.3">1.1.3 []操作符</a></span><ul class="toc-item"><li><span><a href="#1.1.3.1-Series的[]操作" data-toc-modified-id="1.1.3.1-Series的[]操作-2.1.3.1">1.1.3.1 Series的[]操作</a></span></li><li><span><a href="#1.1.3.2-DataFrame的[]操作" data-toc-modified-id="1.1.3.2-DataFrame的[]操作-2.1.3.2">1.1.3.2 DataFrame的[]操作</a></span></li></ul></li></ul></li><li><span><a href="#1.2-布尔索引" data-toc-modified-id="1.2-布尔索引-2.2">1.2 布尔索引</a></span><ul class="toc-item"><li><span><a href="#1.2.1-布尔符号：'&amp;','|','~'：分别代表和and，或or，取反not" data-toc-modified-id="1.2.1-布尔符号：'&amp;','|','~'：分别代表和and，或or，取反not-2.2.1">1.2.1 布尔符号：'&amp;','|','~'：分别代表和and，或or，取反not</a></span><ul class="toc-item"><li><span><a href="#loc和[]中相应位置都能使用布尔列表选择：" data-toc-modified-id="loc和[]中相应位置都能使用布尔列表选择：-2.2.1.1">loc和[]中相应位置都能使用布尔列表选择：</a></span></li></ul></li><li><span><a href="#1.2.2-isin方法" data-toc-modified-id="1.2.2-isin方法-2.2.2">1.2.2 isin方法</a></span></li></ul></li><li><span><a href="#1.3.-快速标量索引" data-toc-modified-id="1.3.-快速标量索引-2.3">1.3. 快速标量索引</a></span></li><li><span><a href="#1.4-区间索引" data-toc-modified-id="1.4-区间索引-2.4">1.4 区间索引</a></span><ul class="toc-item"><li><span><a href="#1.4.1-利用interval_range方法" data-toc-modified-id="1.4.1-利用interval_range方法-2.4.1">1.4.1 利用interval_range方法</a></span></li><li><span><a href="#1.4.2-利用cut将数值列转为区间为元素的分类变量，例如统计数学成绩的区间情况" data-toc-modified-id="1.4.2-利用cut将数值列转为区间为元素的分类变量，例如统计数学成绩的区间情况-2.4.2">1.4.2 利用cut将数值列转为区间为元素的分类变量，例如统计数学成绩的区间情况</a></span></li><li><span><a href="#1.4.3-区间索引的选取" data-toc-modified-id="1.4.3-区间索引的选取-2.4.3">1.4.3 区间索引的选取</a></span><ul class="toc-item"><li><span><a href="#如果想要选取某个区间，先要把分类变量转为区间变量，再使用overlap方法：" data-toc-modified-id="如果想要选取某个区间，先要把分类变量转为区间变量，再使用overlap方法：-2.4.3.1">如果想要选取某个区间，先要把分类变量转为区间变量，再使用overlap方法：</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#二、多级索引" data-toc-modified-id="二、多级索引-3">二、多级索引</a></span><ul class="toc-item"><li><span><a href="#2.1-创建多级索引" data-toc-modified-id="2.1-创建多级索引-3.1">2.1 创建多级索引</a></span><ul class="toc-item"><li><span><a href="#2.1.1-通过from_tuple或from_arrays" data-toc-modified-id="2.1.1-通过from_tuple或from_arrays-3.1.1">2.1.1 通过from_tuple或from_arrays</a></span><ul class="toc-item"><li><span><a href="#2.1.1.1-直接创建元组" data-toc-modified-id="2.1.1.1-直接创建元组-3.1.1.1">2.1.1.1 直接创建元组</a></span></li><li><span><a href="#2.1.1.2-利用zip创建元组" data-toc-modified-id="2.1.1.2-利用zip创建元组-3.1.1.2">2.1.1.2 利用zip创建元组</a></span></li><li><span><a href="#2.1.1.3-通过Array创建" data-toc-modified-id="2.1.1.3-通过Array创建-3.1.1.3">2.1.1.3 通过Array创建</a></span></li></ul></li><li><span><a href="#2.1.2-通过from_product" data-toc-modified-id="2.1.2-通过from_product-3.1.2">2.1.2 通过from_product</a></span></li><li><span><a href="#2.1.3-指定df中的列创建（set_index方法）" data-toc-modified-id="2.1.3-指定df中的列创建（set_index方法）-3.1.3">2.1.3 指定df中的列创建（set_index方法）</a></span></li></ul></li><li><span><a href="#2.2-多层索引切片" data-toc-modified-id="2.2-多层索引切片-3.2">2.2 多层索引切片</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#2.2.1-一般切片" data-toc-modified-id="2.2.1-一般切片-3.2.0.1">2.2.1 一般切片</a></span></li></ul></li><li><span><a href="#2.2.2-第一类特殊情况：由元组构成列表" data-toc-modified-id="2.2.2-第一类特殊情况：由元组构成列表-3.2.1">2.2.2 第一类特殊情况：由元组构成列表</a></span></li><li><span><a href="#2.2.3-第二类特殊情况：由列表构成元组" data-toc-modified-id="2.2.3-第二类特殊情况：由列表构成元组-3.2.2">2.2.3 第二类特殊情况：由列表构成元组</a></span></li></ul></li><li><span><a href="#2.3-多层索引中的slice对象" data-toc-modified-id="2.3-多层索引中的slice对象-3.3">2.3 多层索引中的slice对象</a></span><ul class="toc-item"><li><span><a href="#IndexSlice本质上是对多个Slice对象的包装" data-toc-modified-id="IndexSlice本质上是对多个Slice对象的包装-3.3.1">IndexSlice本质上是对多个Slice对象的包装</a></span></li><li><span><a href="#2.3.1-索引Slice可以与loc一起完成切片操作，主要有两种用法" data-toc-modified-id="2.3.1-索引Slice可以与loc一起完成切片操作，主要有两种用法-3.3.2">2.3.1 索引Slice可以与loc一起完成切片操作，主要有两种用法</a></span><ul class="toc-item"><li><span><a href="#2.3.1.1-loc[idx[*,*]]型" data-toc-modified-id="2.3.1.1-loc[idx[*,*]]型-3.3.2.1">2.3.1.1 loc[idx[*,*]]型</a></span></li><li><span><a href="#2.3.1.2-loc[idx[*,*],idx[*,*]]型" data-toc-modified-id="2.3.1.2-loc[idx[*,*],idx[*,*]]型-3.3.2.2">2.3.1.2 loc[idx[*,*],idx[*,*]]型</a></span></li></ul></li></ul></li><li><span><a href="#2.4.-索引层的交换" data-toc-modified-id="2.4.-索引层的交换-3.4">2.4. 索引层的交换</a></span><ul class="toc-item"><li><span><a href="#2.4.1-swaplevel方法（两层交换）" data-toc-modified-id="2.4.1-swaplevel方法（两层交换）-3.4.1">2.4.1 swaplevel方法（两层交换）</a></span></li><li><span><a href="#2.4.2-reorder_levels方法（多层交换）" data-toc-modified-id="2.4.2-reorder_levels方法（多层交换）-3.4.2">2.4.2 reorder_levels方法（多层交换）</a></span></li></ul></li></ul></li><li><span><a href="#三、索引设定" data-toc-modified-id="三、索引设定-4">三、索引设定</a></span><ul class="toc-item"><li><span><a href="#3.1-index_col参数" data-toc-modified-id="3.1-index_col参数-4.1">3.1 index_col参数</a></span><ul class="toc-item"><li><span><a href="#3.1.1-index_col是read_csv中的一个参数，而不是某一个方法：" data-toc-modified-id="3.1.1-index_col是read_csv中的一个参数，而不是某一个方法：-4.1.1">3.1.1 index_col是read_csv中的一个参数，而不是某一个方法：</a></span></li></ul></li><li><span><a href="#3.2-reindex和reindex_like" data-toc-modified-id="3.2-reindex和reindex_like-4.2">3.2 reindex和reindex_like</a></span><ul class="toc-item"><li><span><a href="#可以选择缺失值的填充方法：fill_value和method（bfill/ffill/nearest），其中method参数必须索引单调" data-toc-modified-id="可以选择缺失值的填充方法：fill_value和method（bfill/ffill/nearest），其中method参数必须索引单调-4.2.1">可以选择缺失值的填充方法：fill_value和method（bfill/ffill/nearest），其中method参数必须索引单调</a></span></li><li><span><a href="#reindex_like的作用为生成一个横纵索引完全与参数列表一致的DataFrame，数据使用被调用的表" data-toc-modified-id="reindex_like的作用为生成一个横纵索引完全与参数列表一致的DataFrame，数据使用被调用的表-4.2.2">reindex_like的作用为生成一个横纵索引完全与参数列表一致的DataFrame，数据使用被调用的表</a></span><ul class="toc-item"><li><span><a href="#如果df_temp单调还可以使用method参数：" data-toc-modified-id="如果df_temp单调还可以使用method参数：-4.2.2.1">如果df_temp单调还可以使用method参数：</a></span></li></ul></li></ul></li><li><span><a href="#3.3.-set_index和reset_index" data-toc-modified-id="3.3.-set_index和reset_index-4.3">3.3. set_index和reset_index</a></span><ul class="toc-item"><li><span><a href="#3.3.1-set_index：从字面意思看，就是将某些列作为索引" data-toc-modified-id="3.3.1-set_index：从字面意思看，就是将某些列作为索引-4.3.1">3.3.1 set_index：从字面意思看，就是将某些列作为索引</a></span><ul class="toc-item"><li><span><a href="#3.3.1.1-使用表内列作为索引：" data-toc-modified-id="3.3.1.1-使用表内列作为索引：-4.3.1.1">3.3.1.1 使用表内列作为索引：</a></span></li><li><span><a href="#3.3.1.2-利用append参数可以将当前索引维持不变" data-toc-modified-id="3.3.1.2-利用append参数可以将当前索引维持不变-4.3.1.2">3.3.1.2 利用append参数可以将当前索引维持不变</a></span></li><li><span><a href="#3.3.1.3-当使用与表长相同的列作为索引（需要先转化为Series，否则报错）：" data-toc-modified-id="3.3.1.3-当使用与表长相同的列作为索引（需要先转化为Series，否则报错）：-4.3.1.3">3.3.1.3 当使用与表长相同的列作为索引（需要先转化为Series，否则报错）：</a></span></li><li><span><a href="#3.3.1.4-可以直接添加多级索引：" data-toc-modified-id="3.3.1.4-可以直接添加多级索引：-4.3.1.4">3.3.1.4 可以直接添加多级索引：</a></span></li></ul></li><li><span><a href="#3.3.2-reset_index方法，它的主要功能是将索引重置" data-toc-modified-id="3.3.2-reset_index方法，它的主要功能是将索引重置-4.3.2">3.3.2 reset_index方法，它的主要功能是将索引重置</a></span><ul class="toc-item"><li><span><a href="#3.3.2.1-默认状态直接恢复到自然数索引：" data-toc-modified-id="3.3.2.1-默认状态直接恢复到自然数索引：-4.3.2.1">3.3.2.1 默认状态直接恢复到自然数索引：</a></span></li><li><span><a href="#3.3.2.2-用level参数指定哪一层被reset，用col_level参数指定set到哪一层：" data-toc-modified-id="3.3.2.2-用level参数指定哪一层被reset，用col_level参数指定set到哪一层：-4.3.2.2">3.3.2.2 用level参数指定哪一层被reset，用col_level参数指定set到哪一层：</a></span></li></ul></li></ul></li><li><span><a href="#3.4.-rename_axis和rename" data-toc-modified-id="3.4.-rename_axis和rename-4.4">3.4. rename_axis和rename</a></span><ul class="toc-item"><li><span><a href="#3.4.1-rename_axis是针对多级索引的方法，作用是修改某一层的索引名，而不是索引标签" data-toc-modified-id="3.4.1-rename_axis是针对多级索引的方法，作用是修改某一层的索引名，而不是索引标签-4.4.1">3.4.1 rename_axis是针对多级索引的方法，作用是修改某一层的索引名，而不是索引标签</a></span></li><li><span><a href="#3.4.2-rename方法用于修改列或者行索引标签，而不是索引名：" data-toc-modified-id="3.4.2-rename方法用于修改列或者行索引标签，而不是索引名：-4.4.2">3.4.2 rename方法用于修改列或者行索引标签，而不是索引名：</a></span></li></ul></li></ul></li><li><span><a href="#四、常用索引型函数" data-toc-modified-id="四、常用索引型函数-5">四、常用索引型函数</a></span><ul class="toc-item"><li><span><a href="#4.1.-where函数" data-toc-modified-id="4.1.-where函数-5.1">4.1. where函数</a></span><ul class="toc-item"><li><span><a href="#4.1.1-当对条件为False的单元进行填充：" data-toc-modified-id="4.1.1-当对条件为False的单元进行填充：-5.1.1">4.1.1 当对条件为False的单元进行填充：</a></span><ul class="toc-item"><li><span><a href="#通过这种方法筛选结果和[]操作符的结果完全一致：" data-toc-modified-id="通过这种方法筛选结果和[]操作符的结果完全一致：-5.1.1.1">通过这种方法筛选结果和[]操作符的结果完全一致：</a></span></li><li><span><a href="#第一个参数为布尔条件，第二个参数为填充值：" data-toc-modified-id="第一个参数为布尔条件，第二个参数为填充值：-5.1.1.2">第一个参数为布尔条件，第二个参数为填充值：</a></span></li></ul></li></ul></li><li><span><a href="#4.2.-mask函数" data-toc-modified-id="4.2.-mask函数-5.2">4.2. mask函数</a></span><ul class="toc-item"><li><span><a href="#mask函数与where功能上相反，其余完全一致，即对条件为True的单元进行填充" data-toc-modified-id="mask函数与where功能上相反，其余完全一致，即对条件为True的单元进行填充-5.2.1">mask函数与where功能上相反，其余完全一致，即对条件为True的单元进行填充</a></span></li></ul></li><li><span><a href="#4.3.-query函数" data-toc-modified-id="4.3.-query函数-5.3">4.3. query函数</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#query函数中的布尔表达式中，下面的符号都是合法的：行列索引名、字符串、and/not/or/&amp;/|/~/not-in/in/==/!=、四则运算符" data-toc-modified-id="query函数中的布尔表达式中，下面的符号都是合法的：行列索引名、字符串、and/not/or/&amp;/|/~/not-in/in/==/!=、四则运算符-5.3.0.1">query函数中的布尔表达式中，下面的符号都是合法的：行列索引名、字符串、and/not/or/&amp;/|/~/not in/in/==/!=、四则运算符</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#五、重复元素处理" data-toc-modified-id="五、重复元素处理-6">五、重复元素处理</a></span><ul class="toc-item"><li><span><a href="#5.1.-duplicated方法" data-toc-modified-id="5.1.-duplicated方法-6.1">5.1. duplicated方法</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#该方法返回了是否重复的布尔列表" data-toc-modified-id="该方法返回了是否重复的布尔列表-6.1.0.1">该方法返回了是否重复的布尔列表</a></span></li><li><span><a href="#可选参数keep默认为first，即首次出现设为不重复，若为last，则最后一次设为不重复，若为False，则所有重复项为True" data-toc-modified-id="可选参数keep默认为first，即首次出现设为不重复，若为last，则最后一次设为不重复，若为False，则所有重复项为True-6.1.0.2">可选参数keep默认为first，即首次出现设为不重复，若为last，则最后一次设为不重复，若为False，则所有重复项为True</a></span></li></ul></li></ul></li><li><span><a href="#5.2.-drop_duplicates方法" data-toc-modified-id="5.2.-drop_duplicates方法-6.2">5.2. drop_duplicates方法</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#从名字上看出为剔除重复项，这在后面章节中的分组操作中可能是有用的，例如需要保留每组的第一个值：" data-toc-modified-id="从名字上看出为剔除重复项，这在后面章节中的分组操作中可能是有用的，例如需要保留每组的第一个值：-6.2.0.1">从名字上看出为剔除重复项，这在后面章节中的分组操作中可能是有用的，例如需要保留每组的第一个值：</a></span></li><li><span><a href="#参数与duplicate函数类似：" data-toc-modified-id="参数与duplicate函数类似：-6.2.0.2">参数与duplicate函数类似：</a></span></li><li><span><a href="#在传入多列时等价于将多列共同视作一个多级索引，比较重复项：" data-toc-modified-id="在传入多列时等价于将多列共同视作一个多级索引，比较重复项：-6.2.0.3">在传入多列时等价于将多列共同视作一个多级索引，比较重复项：</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#六、抽样函数" data-toc-modified-id="六、抽样函数-7">六、抽样函数</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#这里的抽样函数指的就是sample函数" data-toc-modified-id="这里的抽样函数指的就是sample函数-7.0.0.1">这里的抽样函数指的就是sample函数</a></span></li></ul></li></ul></li><li><span><a href="#6.1（a）n为样本量" data-toc-modified-id="6.1（a）n为样本量-7.1">6.1（a）n为样本量</a></span></li><li><span><a href="#6.2（b）frac为抽样比" data-toc-modified-id="6.2（b）frac为抽样比-7.2">6.2（b）frac为抽样比</a></span></li><li><span><a href="#6.3（c）replace为是否放回" data-toc-modified-id="6.3（c）replace为是否放回-7.3">6.3（c）replace为是否放回</a></span></li><li><span><a href="#6.4（d）axis为抽样维度，默认为0，即抽行" data-toc-modified-id="6.4（d）axis为抽样维度，默认为0，即抽行-7.4">6.4（d）axis为抽样维度，默认为0，即抽行</a></span></li><li><span><a href="#6.5（e）weights为样本权重，自动归一化" data-toc-modified-id="6.5（e）weights为样本权重，自动归一化-7.5">6.5（e）weights为样本权重，自动归一化</a></span></li></ul></li><li><span><a href="#七、问题与练习" data-toc-modified-id="七、问题与练习-8">七、问题与练习</a></span><ul class="toc-item"><li><span><a href="#7.1.-问题" data-toc-modified-id="7.1.-问题-8.1">7.1. 问题</a></span><ul class="toc-item"><li><span><a href="#7.1.1-【问题一】-如何更改列或行的顺序？如何交换奇偶行（列）的顺序？" data-toc-modified-id="7.1.1-【问题一】-如何更改列或行的顺序？如何交换奇偶行（列）的顺序？-8.1.1">7.1.1 【问题一】 如何更改列或行的顺序？如何交换奇偶行（列）的顺序？</a></span></li><li><span><a href="#7.1.2-【问题二】-如果要选出DataFrame的某个子集，请给出尽可能多的方法实现。" data-toc-modified-id="7.1.2-【问题二】-如果要选出DataFrame的某个子集，请给出尽可能多的方法实现。-8.1.2">7.1.2 【问题二】 如果要选出DataFrame的某个子集，请给出尽可能多的方法实现。</a></span></li><li><span><a href="#7.1.3-【问题三】-query函数比其他索引方法的速度更慢吗？在什么场合使用什么索引最高效？" data-toc-modified-id="7.1.3-【问题三】-query函数比其他索引方法的速度更慢吗？在什么场合使用什么索引最高效？-8.1.3">7.1.3 【问题三】 query函数比其他索引方法的速度更慢吗？在什么场合使用什么索引最高效？</a></span></li><li><span><a href="#7.1.4-【问题四】-单级索引能使用Slice对象吗？能的话怎么使用，请给出一个例子。" data-toc-modified-id="7.1.4-【问题四】-单级索引能使用Slice对象吗？能的话怎么使用，请给出一个例子。-8.1.4">7.1.4 【问题四】 单级索引能使用Slice对象吗？能的话怎么使用，请给出一个例子。</a></span></li><li><span><a href="#7.1.5-【问题五】-如何快速找出某一列的缺失值所在索引？" data-toc-modified-id="7.1.5-【问题五】-如何快速找出某一列的缺失值所在索引？-8.1.5">7.1.5 【问题五】 如何快速找出某一列的缺失值所在索引？</a></span></li><li><span><a href="#7.1.6-【问题六】-索引设定中的所有方法分别适用于哪些场合？怎么直接把某个DataFrame的索引换成任意给定同长度的索引？" data-toc-modified-id="7.1.6-【问题六】-索引设定中的所有方法分别适用于哪些场合？怎么直接把某个DataFrame的索引换成任意给定同长度的索引？-8.1.6">7.1.6 【问题六】 索引设定中的所有方法分别适用于哪些场合？怎么直接把某个DataFrame的索引换成任意给定同长度的索引？</a></span></li><li><span><a href="#7.1.7-【问题七】-对于多层索引，怎么对内层进行条件筛选？" data-toc-modified-id="7.1.7-【问题七】-对于多层索引，怎么对内层进行条件筛选？-8.1.7">7.1.7 【问题七】 对于多层索引，怎么对内层进行条件筛选？</a></span></li><li><span><a href="#7.1.8-【问题八】-swaplevel中的axis参数为1时，代表什么意思？i和j只能是数值型吗？" data-toc-modified-id="7.1.8-【问题八】-swaplevel中的axis参数为1时，代表什么意思？i和j只能是数值型吗？-8.1.8">7.1.8 【问题八】 swaplevel中的axis参数为1时，代表什么意思？i和j只能是数值型吗？</a></span></li></ul></li><li><span><a href="#7.2.-练习" data-toc-modified-id="7.2.-练习-8.2">7.2. 练习</a></span><ul class="toc-item"><li><span><a href="#7.2.1【练习一】-现有一份关于UFO的数据集，请解决下列问题：" data-toc-modified-id="7.2.1【练习一】-现有一份关于UFO的数据集，请解决下列问题：-8.2.1">7.2.1【练习一】 现有一份关于UFO的数据集，请解决下列问题：</a></span></li><li><span><a href="#7.2.2（a）在所有被观测时间超过60s的时间中，哪个形状最多？" data-toc-modified-id="7.2.2（a）在所有被观测时间超过60s的时间中，哪个形状最多？-8.2.2">7.2.2（a）在所有被观测时间超过60s的时间中，哪个形状最多？</a></span></li><li><span><a href="#7.2.3（b）对经纬度进行划分：-180°至180°以30°为一个经度划分，-90°至90°以18°为一个维度划分，请问哪个区域中报告的UFO事件数量最多？" data-toc-modified-id="7.2.3（b）对经纬度进行划分：-180°至180°以30°为一个经度划分，-90°至90°以18°为一个维度划分，请问哪个区域中报告的UFO事件数量最多？-8.2.3">7.2.3（b）对经纬度进行划分：-180°至180°以30°为一个经度划分，-90°至90°以18°为一个维度划分，请问哪个区域中报告的UFO事件数量最多？</a></span></li><li><span><a href="#7.2.2-【练习二】-现有一份关于口袋妖怪的数据集，请解决下列问题：" data-toc-modified-id="7.2.2-【练习二】-现有一份关于口袋妖怪的数据集，请解决下列问题：-8.2.4">7.2.2 【练习二】 现有一份关于口袋妖怪的数据集，请解决下列问题：</a></span><ul class="toc-item"><li><span><a href="#7.2.2.1（a）双属性的Pokemon占总体比例的多少？" data-toc-modified-id="7.2.2.1（a）双属性的Pokemon占总体比例的多少？-8.2.4.1">7.2.2.1（a）双属性的Pokemon占总体比例的多少？</a></span></li><li><span><a href="#7.2.2.2（b）在所有种族值（Total）不小于580的Pokemon中，非神兽（Legendary=False）的比例为多少？" data-toc-modified-id="7.2.2.2（b）在所有种族值（Total）不小于580的Pokemon中，非神兽（Legendary=False）的比例为多少？-8.2.4.2">7.2.2.2（b）在所有种族值（Total）不小于580的Pokemon中，非神兽（Legendary=False）的比例为多少？</a></span></li><li><span><a href="#7.2.2.3（c）在第一属性为格斗系（Fighting）的Pokemon中，物攻排名前三高的是哪些？" data-toc-modified-id="7.2.2.3（c）在第一属性为格斗系（Fighting）的Pokemon中，物攻排名前三高的是哪些？-8.2.4.3">7.2.2.3（c）在第一属性为格斗系（Fighting）的Pokemon中，物攻排名前三高的是哪些？</a></span></li><li><span><a href="#7.2.2.4（d）请问六项种族指标（HP、物攻、特攻、物防、特防、速度）极差的均值最大的是哪个属性（只考虑第一属性，且均值是对属性而言）？" data-toc-modified-id="7.2.2.4（d）请问六项种族指标（HP、物攻、特攻、物防、特防、速度）极差的均值最大的是哪个属性（只考虑第一属性，且均值是对属性而言）？-8.2.4.4">7.2.2.4（d）请问六项种族指标（HP、物攻、特攻、物防、特防、速度）极差的均值最大的是哪个属性（只考虑第一属性，且均值是对属性而言）？</a></span></li><li><span><a href="#7.2.2.5（e）哪个属性（只考虑第一属性）神兽占总Pokemon的比例最高？该属性神兽的种族值也是最高的吗？" data-toc-modified-id="7.2.2.5（e）哪个属性（只考虑第一属性）神兽占总Pokemon的比例最高？该属性神兽的种族值也是最高的吗？-8.2.4.5">7.2.2.5（e）哪个属性（只考虑第一属性）神兽占总Pokemon的比例最高？该属性神兽的种族值也是最高的吗？</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 第二章 索引

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('data/table.csv',index_col='ID')
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# # 一、单级索引

# %% [markdown]
# ## 1.1 loc方法、iloc方法、[]操作符
# 最常用的索引方法可能就是这三类，其中iloc表示位置索引，loc表示标签索引，[]也具有很大的便利性，各有特点

# %% [markdown]
# ### 1.1.1 loc方法

# %% [markdown]
# #### 1.1.1.1 单行索引

# %%
df.shape
# Out:
# (35, 8)

# %%
df.loc[1103]
# Out:
# School          S_1
# Class           C_1
# Gender            M
# Address    street_2
# Height          186
# Weight           82
# Math           87.2
# Physics          B+
# Name: 1103, dtype: object

# %% [markdown]
# #### 1.1.1.2 多行索引

# %%
df.loc[[1102,2304]]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-

# %% [markdown]
# （注意：所有在loc中使用的切片全部包含右端点！这是因为如果作为Pandas的使用者，那么肯定不太关心最后一个标签再往后一位是什么，但是如果是左闭右开，那么就很麻烦，先要知道再后面一列的名字是什么，非常不方便，因此Pandas中将loc设计为左右全闭）

# %%
df.loc[1304:2103].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1304    S_1   C_3      M  street_2     195      70  85.2       A
# 1305    S_1   C_3      F  street_5     187      69  61.7      B-
# 2101    S_2   C_1      M  street_7     174      84  83.3       C
# 2102    S_2   C_1      F  street_6     161      61  50.6      B+
# 2103    S_2   C_1      M  street_4     157      61  52.5      B-

# %%
df.loc[2402::-1].head() # [start:end:step]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2402    S_2   C_4      M  street_7     166      82  48.7       B
# 2401    S_2   C_4      F  street_2     192      62  45.3       A
# 2305    S_2   C_3      M  street_4     187      73  48.9       B
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-
# 2303    S_2   C_3      F  street_7     190      99  65.9       C

# %% [markdown]
# #### 1.1.1.3 单列索引

# %%
df.loc[:,'Height'].head()
# Out:
# ID
# 1101    173
# 1102    192
# 1103    186
# 1104    167
# 1105    159
# Name: Height, dtype: int64

# %% [markdown]
# #### 1.1.1.4 多列索引

# %%
df.loc[:,['Height','Math']].head()
# Out:
#       Height  Math
# ID
# 1101     173  34.0
# 1102     192  32.5
# 1103     186  87.2
# 1104     167  80.4
# 1105     159  84.8

# %%
df.loc[:,'Height':'Math'].head()
# Out:
#       Height  Weight  Math
# ID
# 1101     173      63  34.0
# 1102     192      73  32.5
# 1103     186      82  87.2
# 1104     167      81  80.4
# 1105     159      64  84.8

# %% [markdown]
# #### 1.1.1.5 联合索引

# %%
df.loc[1102:2401:3,'Height':'Math'].head() # [start:end:step]
# Out:
#       Height  Weight  Math
# ID
# 1102     192      73  32.5
# 1105     159      64  84.8
# 1203     160      53  58.8
# 1301     161      68  31.5
# 1304     195      70  85.2

# %% [markdown]
# #### 1.1.1.6 函数式索引

# %%
df.loc[lambda x:x['Gender']=='M'].head()
#loc中使用的函数，传入参数就是前面的df
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+

# %%
#这里的例子表示，loc中能够传入函数，并且函数的输入值是整张表，输出为标量、切片、合法列表（元素出现在索引中）、合法索引
def f(x):
    return [1101,1103]
df.loc[f]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+

# %% [markdown]
# #### 1.1.1.7 布尔索引（将重点在第2节介绍）

# %%
df.loc[df['Address'].isin(['street_7','street_4'])].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2101    S_2   C_1      M  street_7     174      84  83.3       C

# %%
df.loc[[True if i[-1]=='4' or i[-1]=='7' else False for i in df['Address'].values]].head() # 列表推导式
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2101    S_2   C_1      M  street_7     174      84  83.3       C

# %%
小节：本质上说，loc中能传入的只有布尔列表和索引子集构成的列表，只要把握这个原则就很容易理解上面那些操作

# %% [markdown]
# ### 1.1.2 iloc方法（注意与loc不同，切片右端点不包含，索引从0开始）

# %% [markdown]
# #### 1.1.2.1 单行索引

# %%
df.iloc[3]  # 索引从0开始
# Out:
# School          S_1
# Class           C_1
# Gender            F
# Address    street_2
# Height          167
# Weight           81
# Math           80.4
# Physics          B-
# Name: 1104, dtype: object

# %% [markdown]
# #### 1.1.2.2 多行索引

# %%
df.iloc[3:5]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 1.1.2.3 单列索引

# %%
df.iloc[:,3].head() # 索引从0开始
# Out:
# ID
# 1101    street_1
# 1102    street_2
# 1103    street_2
# 1104    street_2
# 1105    street_4
# Name: Address, dtype: object

# %% [markdown]
# #### 1.1.2.4 多列索引

# %%
df.iloc[:,7::-2].head()
# Out:
#      Physics  Weight   Address Class
# ID
# 1101      A+      63  street_1   C_1
# 1102      B+      73  street_2   C_1
# 1103      B+      82  street_2   C_1
# 1104      B-      81  street_2   C_1
# 1105      B+      64  street_4   C_1

# %% [markdown]
# #### 1.1.2.5 混合索引

# %%
df.iloc[3::4,7::-2].head()
# Out:
#      Physics  Weight   Address Class
# ID
# 1104      B-      81  street_2   C_1
# 1203      A+      53  street_6   C_2
# 1302      A-      57  street_1   C_3
# 2101       C      84  street_7   C_1
# 2105       A      81  street_4   C_1

# %% [markdown]
# #### 1.1.2.6 函数式索引

# %%
df.iloc[lambda x:[3]].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-

# %% [markdown]
# 小节：iloc中接收的参数只能为整数或整数列表或布尔列表，不能使用布尔Series，如果要用就必须如下把values拿出来

# %% [markdown]
# ### 1.1.3 []操作符
# #### 1.1.3.1 Series的[]操作
# ##### 1.1.3.1.1 单元素索引

# %%
s = pd.Series(df['Math'],index=df.index)
s[1101]
# 使用的是索引标签
# Out:
# 34.0

# %% [markdown]
# ##### 1.1.3.1.2 多行索引

# %%
s[0:4]
# 使用的是绝对位置的整数切片，与元素无关，这里容易混淆
# Out:
# ID
# 1101    34.0
# 1102    32.5
# 1103    87.2
# 1104    80.4
# Name: Math, dtype: float64

# %% [markdown]
# ##### 1.1.3.1.3 函数式索引

# %%
s[lambda x: x.index[16::-6]]
# 注意使用lambda函数时，直接切片(如：s[lambda x: 16::-6])就报错，此时使用的不是绝对位置切片，而是元素切片，非常易错
# Out:
# ID
# 2102    50.6
# 1301    31.5
# 1105    84.8
# Name: Math, dtype: float64

# %% [markdown]
# ##### 1.1.3.1.4 布尔索引

# %%
s[s>80]
# Out:
# ID
# 1103    87.2
# 1104    80.4
# 1105    84.8
# 1201    97.0
# 1302    87.7
# 1304    85.2
# 2101    83.3
# 2205    85.4
# 2304    95.5
# Name: Math, dtype: float64

# %% [markdown]
# ** 【注意】如果不想陷入困境，请不要在行索引为浮点时使用[]操作符，因为在Series中[]的浮点切片并不是进行位置比较，而是值比较，非常特殊 **

# %%
s_int = pd.Series([1,2,3,4],index=[1,3,5,6])
s_float = pd.Series([1,2,3,4],index=[1.,3.,5.,6.])
s_int
# Out:
# 1    1
# 3    2
# 5    3
# 6    4
# dtype: int64

# %%
s_int[2:]
# Out:
# 5    3
# 6    4
# dtype: int64

# %%
s_float
# Out:
# 1.0    1
# 3.0    2
# 5.0    3
# 6.0    4
# dtype: int64

# %%
# 注意和s_int[2:]结果不一样了，因为2这里是元素而不是位置
s_float[2:]
# Out:
# 3.0    2
# 5.0    3
# 6.0    4
# dtype: int64

# %% [markdown]
# #### 1.1.3.2 DataFrame的[]操作
# ##### 1.1.3.2.1 单行索引

# %%
df[1:2]
# 这里非常容易写成df['label']，会报错
# 同Series使用了绝对位置切片
# 如果想要获得某一个元素，可用如下get_loc方法：
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+

# %%
row = df.index.get_loc(1102)
df[row:row+1]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+

# %% [markdown]
# ##### 1.1.3.2.2 多行索引

# %%
#用切片，如果是选取指定的某几行，推荐使用loc，否则很可能报错
df[3:5]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# ##### 1.1.3.2.3 单列索引

# %%
df['School'].head()
# Out:
# ID
# 1101    S_1
# 1102    S_1
# 1103    S_1
# 1104    S_1
# 1105    S_1
# Name: School, dtype: object

# %% [markdown]
# ##### 1.1.3.2.4 多列索引

# %%
df[['School','Math']].head()
# Out:
#      School  Math
# ID
# 1101    S_1  34.0
# 1102    S_1  32.5
# 1103    S_1  87.2
# 1104    S_1  80.4
# 1105    S_1  84.8

# %% [markdown]
# ##### 1.1.3.2.5 函数式索引

# %%
df[lambda x:['Math','Physics']].head()
# Out:
#       Math Physics
# ID
# 1101  34.0      A+
# 1102  32.5      B+
# 1103  87.2      B+
# 1104  80.4      B-
# 1105  84.8      B+

# %% [markdown]
# ##### 1.1.3.2.6 布尔索引

# %%
df[df['Gender']=='F'].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1204    S_1   C_2      F  street_5     162      63  33.8       B

# %% [markdown]
# ** 小节：一般来说，[]操作符常用于列选择或布尔选择，尽量避免行的选择 **

# %% [markdown]
# ## 1.2 布尔索引
# ### 1.2.1 布尔符号：'&','|','~'：分别代表和and，或or，取反not

# %%
df[(df['Gender']=='F')&(df['Address']=='street_2')].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 2401    S_2   C_4      F  street_2     192      62  45.3       A
# 2404    S_2   C_4      F  street_2     160      84  67.7       B

# %%
df[(df['Math']>85)|(df['Address']=='street_7')].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1302    S_1   C_3      F  street_1     175      57  87.7      A-
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 1304    S_1   C_3      M  street_2     195      70  85.2       A

# %%
df[~((df['Math']>75)|(df['Address']=='street_1'))].head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1204    S_1   C_2      F  street_5     162      63  33.8       B
# 1205    S_1   C_2      F  street_6     167      63  68.4      B-

# %% [markdown]
# #### loc和[]中相应位置都能使用布尔列表选择：

# %%
df.loc[df['Math']>60,df.columns=='Physics'].head()
#思考：为什么df.loc[df['Math']>60,(df[:8]['Address']=='street_6').values].head()得到和上述结果一样？values能去掉吗？
# Out:
#      Physics
# ID
# 1103      B+
# 1104      B-
# 1105      B+
# 1201      A-
# 1202      B-

# %%
df[:8]['Address']=='street_6'
# Out:
# ID
# 1101    False
# 1102    False
# 1103    False
# 1104    False
# 1105    False
# 1201    False
# 1202    False
# 1203     True
# Name: Address, dtype: bool

# %% [markdown]
# ### 1.2.2 isin方法

# %%
df[df['Address'].isin(['street_1','street_4'])&df['Physics'].isin(['A','A+'])]
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2203    S_2   C_2      M  street_4     155      91  73.8      A+

# %%
# 上面也可以用字典方式写：
df[df[['Address','Physics']].isin({'Address':['street_1','street_4'],'Physics':['A','A+']}).all(1)]
# all与&的思路是类似的，其中的1代表按照跨列方向判断是否全为True
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2203    S_2   C_2      M  street_4     155      91  73.8      A+

# %% [markdown]
# ## 1.3. 快速标量索引
# 当只需要取一个元素时，at和iat方法能够提供更快的实现：

# %%
display(df.at[1101,'School'])
display(df.loc[1101,'School'])
display(df.iat[0,0])
display(df.iloc[0,0])
#可尝试去掉注释对比时间
# %timeit df.at[1101,'School']
# %timeit df.loc[1101,'School']
# %timeit df.iat[0,0]
# %timeit df.iloc[0,0]
# Out:
# 'S_1'
# 'S_1'
# 'S_1'
# 'S_1'
# 4.37 µs ± 326 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 7.05 µs ± 425 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 4.39 µs ± 86.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 7.04 µs ± 402 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# ## 1.4 区间索引
#
# 此处介绍并不是说只能在单级索引中使用区间索引，只是作为一种特殊类型的索引方式，在此处先行介绍
#
# ### 1.4.1 利用interval_range方法

# %%
pd.interval_range(start=0,end=5)
# closed参数可选'left''right''both''neither'，默认左开右闭
# Out:
# IntervalIndex([(0, 1], (1, 2], (2, 3], (3, 4], (4, 5]],
#               closed='right',
#               dtype='interval[int64]')

# %%
pd.interval_range(start=0,periods=8,freq=5)
#periods参数控制区间个数，freq控制步长
# Out:
# IntervalIndex([(0, 5], (5, 10], (10, 15], (15, 20], (20, 25], (25, 30], (30, 35], (35, 40]],
#               closed='right',
#               dtype='interval[int64]')

# %% [markdown]
# ### 1.4.2 利用cut将数值列转为区间为元素的分类变量，例如统计数学成绩的区间情况

# %%
math_interval = pd.cut(df['Math'],bins=[0,40,60,80,100])
#注意，如果没有类型转换，此时并不是区间类型，而是category类型
math_interval.head()
# Out:
# ID
# 1101      (0, 40]
# 1102      (0, 40]
# 1103    (80, 100]
# 1104    (80, 100]
# 1105    (80, 100]
# Name: Math, dtype: category
# Categories (4, interval[int64]): [(0, 40] < (40, 60] < (60, 80] < (80, 100]]

# %% [markdown]
# ### 1.4.3 区间索引的选取

# %%
df_i = df.join(math_interval,rsuffix='_interval')[['Math','Math_interval']]\
            .reset_index().set_index('Math_interval')
# rsuffix：添加后缀
df_i.head()
# Out:
#                  ID  Math
# Math_interval
# (0, 40]        1101  34.0
# (0, 40]        1102  32.5
# (80, 100]      1103  87.2
# (80, 100]      1104  80.4
# (80, 100]      1105  84.8

# %%
df_i.loc[[65,90]].head()
# Out:
#                  ID  Math
# Math_interval
# (60, 80]       1202  63.5
# (60, 80]       1205  68.4
# (60, 80]       1305  61.7
# (60, 80]       2104  72.2
# (60, 80]       2202  68.5

# %% [markdown]
# #### 如果想要选取某个区间，先要把分类变量转为区间变量，再使用overlap方法：

# %%
pd.Interval(70, 85)
# Out:
# Interval(70, 85, closed='right')

# %%
#df_i.loc[pd.Interval(70,75)].head() 报错
df_i[df_i.index.astype('interval').overlaps(pd.Interval(70, 85))].head()
# overlap：重叠
#只要索引与(70,85]这个区间有交集就会被选中，注意pd.Interval默认构造区间都是左开右闭，可选closed参数right,left,both,neither
# Out:
#                  ID  Math
# Math_interval
# (80, 100]      1103  87.2
# (80, 100]      1104  80.4
# (80, 100]      1105  84.8
# (80, 100]      1201  97.0
# (60, 80]       1202  63.5

# %% [markdown]
# # 二、多级索引
# ## 2.1 创建多级索引
# ### 2.1.1 通过from_tuple或from_arrays
# #### 2.1.1.1 直接创建元组

# %%
tuples = [('A','a'),('A','b'),('B','a'),('B','b')] # 元组
mul_index = pd.MultiIndex.from_tuples(tuples, names=('Upper', 'Lower'))
mul_index
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %%
pd.DataFrame({'Score':['perfect','good','fair','bad']}, index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %% [markdown]
# #### 2.1.1.2 利用zip创建元组

# %%
L1 = list('AABB')
L2 = list('abab')
tuples = list(zip(L1,L2))
mul_index = pd.MultiIndex.from_tuples(tuples, names=('Upper', 'Lower'))
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %% [markdown]
# #### 2.1.1.3 通过Array创建

# %%
arrays = [['A','a'],['A','b'],['B','a'],['B','b']]
mul_index = pd.MultiIndex.from_tuples(arrays, names=('Upper', 'Lower'))
pd.DataFrame({'Score':['perfect','good','fair','bad']},index=mul_index)
# Out:
#                Score
# Upper Lower
# A     a      perfect
#       b         good
# B     a         fair
#       b          bad

# %%
mul_index
#由此看出内部自动转成元组
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %% [markdown]
# ### 2.1.2 通过from_product

# %%
L1 = ['A','B']
L2 = ['a','b']
pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
#两两相乘
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            names=['Upper', 'Lower'])

# %% [markdown]
# ### 2.1.3 指定df中的列创建（set_index方法）

# %%
df_using_mul = df.set_index(['Class','Address'])
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %% [markdown]
# ## 2.2 多层索引切片

# %%
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %% [markdown]
# #### 2.2.1 一般切片

# %%
#df_using_mul.loc['C_2','street_5']
#当索引不排序时，单个索引会报出性能警告
#df_using_mul.index.is_lexsorted()
#该函数检查是否排序
df_using_mul.sort_index().loc['C_2','street_5']
# df_using_mul.sort_index().index.is_lexsorted()
# Out:
# True

# %%
#df_using_mul.loc[('C_2','street_5'):] 报错
#当不排序时，不能使用多层切片
df_using_mul.sort_index().loc[('C_2','street_6'):('C_3','street_4')]
#注意此处由于使用了loc，因此仍然包含右端点
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_6    S_1      M     160      53  58.8      A+
#       street_6    S_1      F     167      63  68.4      B-
#       street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_1    S_1      F     175      57  87.7      A-
#       street_2    S_1      M     195      70  85.2       A
#       street_4    S_1      M     161      68  31.5      B+
#       street_4    S_2      F     157      78  72.3      B+
#       street_4    S_2      M     187      73  48.9       B

# %%
df_using_mul.sort_index().loc[('C_2','street_7'):'C_3'].head()
#非元组也是合法的，表示选中该层所有元素
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_1    S_1      F     175      57  87.7      A-
#       street_2    S_1      M     195      70  85.2       A
#       street_4    S_1      M     161      68  31.5      B+

# %% [markdown]
# ### 2.2.2 第一类特殊情况：由元组构成列表

# %%
df_using_mul.sort_index().loc[[('C_2','street_7'),('C_3','street_2')]]
#表示选出某几个元素，精确到最内层索引
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_2    S_1      M     195      70  85.2       A

# %% [markdown]
# ### 2.2.3 第二类特殊情况：由列表构成元组

# %%
df_using_mul.sort_index().loc[(['C_2','C_3'],['street_4','street_7']),:]
#选出第一层在‘C_2’和'C_3'中且第二层在'street_4'和'street_7'中的行
# 相当于进行笛卡尔积
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_2   street_4    S_1      F     176      94  63.5      B-
#       street_4    S_2      M     155      91  73.8      A+
#       street_7    S_2      F     194      77  68.5      B+
#       street_7    S_2      F     183      76  85.4       B
# C_3   street_4    S_1      M     161      68  31.5      B+
#       street_4    S_2      F     157      78  72.3      B+
#       street_4    S_2      M     187      73  48.9       B
#       street_7    S_1      M     188      82  49.7       B
#       street_7    S_2      F     190      99  65.9       C

# %% [markdown]
# ## 2.3 多层索引中的slice对象
# slice：薄片

# %%
L1,L2 = ['A','B'],['a','b','c']
mul_index1 = pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
L3,L4 = ['D','E','F'],['d','e','f']
mul_index2 = pd.MultiIndex.from_product([L3,L4],names=('Big', 'Small'))
df_s = pd.DataFrame(np.random.rand(6,9),index=mul_index1,columns=mul_index2)
df_s
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     a      0.481615  0.066337  0.612521  0.496806  0.170635  0.313922
#       b      0.423103  0.766020  0.874904  0.777403  0.467491  0.122896
#       c      0.976692  0.992853  0.679045  0.993711  0.768666  0.241913
# B     a      0.668110  0.747240  0.006313  0.851428  0.769350  0.864411
#       b      0.333440  0.391835  0.682967  0.312125  0.968533  0.827066
#       c      0.201805  0.081384  0.438649  0.616895  0.509728  0.683276
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     a      0.123945  0.521471  0.224466
#       b      0.688875  0.142464  0.019028
#       c      0.130953  0.897912  0.182568
# B     a      0.678638  0.058836  0.315499
#       b      0.462304  0.084384  0.859964
#       c      0.303746  0.611885  0.498872

# %%
idx=pd.IndexSlice

# %% [markdown]
# ### IndexSlice本质上是对多个Slice对象的包装

# %%
idx[1:9:2,'A':'C','start':'end':2]
# Out:
# (slice(1, 9, 2), slice('A', 'C', None), slice('start', 'end', 2))

# %% [markdown]
# ### 2.3.1 索引Slice可以与loc一起完成切片操作，主要有两种用法
# #### 2.3.1.1 loc\[idx\[\*,\*\]\]型
# 第一个星号表示行，第二个表示列，且使用布尔索引时，需要索引对齐

# %%
#例子1
df_s.loc[idx['B':,df_s.iloc[0]>0.6]]
#df_s.loc[idx['B':,df_s.iloc[:,0]>0.6]] #索引没有对齐报错
# Out:
# Big                 D
# Small               f
# Upper Lower
# B     a      0.006313
#       b      0.682967
#       c      0.438649

# %%
#例子2
df_s.loc[idx[df_s.iloc[:,0]>0.6,:('E','f')]]
# Out:
# Big                 D                             E
# Small               d         e         f         d         e         f
# Upper Lower
# A     c      0.976692  0.992853  0.679045  0.993711  0.768666  0.241913
# B     a      0.668110  0.747240  0.006313  0.851428  0.769350  0.864411

# %% [markdown]
# #### 2.3.1.2 loc\[idx\[\*,\*],idx\[\*,\*\]\]型
# * 这里与上面的区别在于上面中的loc是没有逗号隔开的，但这里是用逗号隔开，前面一个idx表示行索引，后面一个idx为列索引
# * 这种用法非常灵活，因此多举几个例子方便理解

# %%
#例子1
df_s.loc[idx['A'],idx['D':]]
#后面的层出现，则前面的层必须出现
#df_s.loc[idx['a'],idx['D':]] #报错
# Out:
# Big           D                             E                             F  \
# Small         d         e         f         d         e         f         d
# Lower
# a      0.481615  0.066337  0.612521  0.496806  0.170635  0.313922  0.123945
# b      0.423103  0.766020  0.874904  0.777403  0.467491  0.122896  0.688875
# c      0.976692  0.992853  0.679045  0.993711  0.768666  0.241913  0.130953
#
# Big
# Small         e         f
# Lower
# a      0.521471  0.224466
# b      0.142464  0.019028
# c      0.897912  0.182568

# %%
#例子2
df_s.loc[idx[:'B','b':],:] #举这个例子是为了说明（1）可以在相应level使用切片（2）某一个idx可以用:代替表示全选
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     b      0.423103  0.766020  0.874904  0.777403  0.467491  0.122896
#       c      0.976692  0.992853  0.679045  0.993711  0.768666  0.241913
# B     b      0.333440  0.391835  0.682967  0.312125  0.968533  0.827066
#       c      0.201805  0.081384  0.438649  0.616895  0.509728  0.683276
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     b      0.688875  0.142464  0.019028
#       c      0.130953  0.897912  0.182568
# B     b      0.462304  0.084384  0.859964
#       c      0.303746  0.611885  0.498872

# %%
#例子3
df_s.iloc[:,0]>0.6
# Out:
# Upper  Lower
# A      a        False
#        b        False
#        c         True
# B      a         True
#        b        False
#        c        False
# Name: (D, d), dtype: bool

# %%
df_s.loc[idx[:'B',df_s.iloc[:,0]>0.6],:] #这个例子表示相应位置还可以使用布尔索引
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     c      0.976692  0.992853  0.679045  0.993711  0.768666  0.241913
# B     a      0.668110  0.747240  0.006313  0.851428  0.769350  0.864411
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     c      0.130953  0.897912  0.182568
# B     a      0.678638  0.058836  0.315499

# %%
#例子4
#特别要注意，loc[idx[\*,\*],idx[\*,\*]]型中的布尔索引是可以索引不对齐的，只需要长度一样，比如下面这个例子
df_s.loc[idx[:'B',(df_s.iloc[0]>0.6)[:6]],:]
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     c      0.976692  0.992853  0.679045  0.993711  0.768666  0.241913
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     c      0.130953  0.897912  0.182568

# %%
#例子5
df_s.loc[idx[:'B','c':,(df_s.iloc[:,0]>0.6)],:]
#idx中层数k1大于df层数k2时，idx前k2个参数若相应位置是元素或者元素切片，则表示相应df层的元素筛选，同时也可以选择用同长度bool序列
#idx后面多出来的参数只能选择同bool序列，这样设计的目的是可以将元素筛选和条件筛选同时运用
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     c      0.976692  0.992853  0.679045  0.993711  0.768666  0.241913
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     c      0.130953  0.897912  0.182568

# %%
#例子6
df_s.loc[idx[:'B',(df_s.iloc[:,0]>0.6),(df_s.iloc[:,0]>0.6)],:] #这个就不是元素筛选而是条件筛选
#df_s.loc[idx[:'B',(df_s.iloc[:,0]>0.6),'c',:]] #报错
#df_s.loc[idx[:'c','B',(df_s.iloc[:,0]>0.6),:]] #报错
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     c      0.976692  0.992853  0.679045  0.993711  0.768666  0.241913
# B     a      0.668110  0.747240  0.006313  0.851428  0.769350  0.864411
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     c      0.130953  0.897912  0.182568
# B     a      0.678638  0.058836  0.315499

# %% [markdown]
# ## 2.4. 索引层的交换
# ### 2.4.1 swaplevel方法（两层交换）

# %%
df_using_mul.head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Class Address
# C_1   street_1    S_1      M     173      63  34.0      A+
#       street_2    S_1      F     192      73  32.5      B+
#       street_2    S_1      M     186      82  87.2      B+
#       street_2    S_1      F     167      81  80.4      B-
#       street_4    S_1      F     159      64  84.8      B+

# %%
df_using_mul.swaplevel(i=1,j=0,axis=0).sort_index().head()
# Out:
#                School Gender  Height  Weight  Math Physics
# Address  Class
# street_1 C_1      S_1      M     173      63  34.0      A+
#          C_2      S_2      M     175      74  47.2      B-
#          C_3      S_1      F     175      57  87.7      A-
# street_2 C_1      S_1      F     192      73  32.5      B+
#          C_1      S_1      M     186      82  87.2      B+

# %% [markdown]
# ### 2.4.2 reorder_levels方法（多层交换）

# %%
df_muls = df.set_index(['School','Class','Address'])
df_muls.head()
# Out:
#                       Gender  Height  Weight  Math Physics
# School Class Address
# S_1    C_1   street_1      M     173      63  34.0      A+
#              street_2      F     192      73  32.5      B+
#              street_2      M     186      82  87.2      B+
#              street_2      F     167      81  80.4      B-
#              street_4      F     159      64  84.8      B+

# %%
df_muls.reorder_levels([2,0,1],axis=0).sort_index().head()
# Out:
#                       Gender  Height  Weight  Math Physics
# Address  School Class
# street_1 S_1    C_1        M     173      63  34.0      A+
#                 C_3        F     175      57  87.7      A-
#          S_2    C_2        M     175      74  47.2      B-
# street_2 S_1    C_1        F     192      73  32.5      B+
#                 C_1        M     186      82  87.2      B+

# %%
#如果索引有name，可以直接使用name
df_muls.reorder_levels(['Address','School','Class'],axis=0).sort_index().head()
# Out:
#                       Gender  Height  Weight  Math Physics
# Address  School Class
# street_1 S_1    C_1        M     173      63  34.0      A+
#                 C_3        F     175      57  87.7      A-
#          S_2    C_2        M     175      74  47.2      B-
# street_2 S_1    C_1        F     192      73  32.5      B+
#                 C_1        M     186      82  87.2      B+

# %% [markdown]
# # 三、索引设定
# ## 3.1 index_col参数
# ### 3.1.1 index_col是read_csv中的一个参数，而不是某一个方法：

# %%
pd.read_csv('data/table.csv',index_col=['Address','School']).head()
# Out:
#                 Class    ID Gender  Height  Weight  Math Physics
# Address  School
# street_1 S_1      C_1  1101      M     173      63  34.0      A+
# street_2 S_1      C_1  1102      F     192      73  32.5      B+
#          S_1      C_1  1103      M     186      82  87.2      B+
#          S_1      C_1  1104      F     167      81  80.4      B-
# street_4 S_1      C_1  1105      F     159      64  84.8      B+

# %% [markdown]
# ## 3.2 reindex和reindex_like
# reindex是指重新索引，它的重要特性在于索引对齐，很多时候用于重新排序

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.reindex(index=[1101,1203,1206,2402])
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1203    S_1   C_2      M  street_6   160.0    53.0  58.8      A+
# 1206    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 2402    S_2   C_4      M  street_7   166.0    82.0  48.7       B

# %%
df.reindex(columns=['Height','Gender','Average']).head()
# Out:
#       Height Gender  Average
# ID
# 1101     173      M      NaN
# 1102     192      F      NaN
# 1103     186      M      NaN
# 1104     167      F      NaN
# 1105     159      F      NaN

# %% [markdown]
# ### 可以选择缺失值的填充方法：fill_value和method（bfill/ffill/nearest），其中method参数必须索引单调

# %%
df.reindex(index=[1101,1203,1206,2402],method='bfill')
#这里的单调是指df必须索引经过排序，否则报错
#bfill表示用所在索引1206的后一个有效行填充，ffill为前一个有效行，nearest是指最近的
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1206    S_1   C_3      M  street_4     161      68  31.5      B+
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %%
df.reindex(index=[1101,1203,1206,2402],method='nearest')
#数值上1205比1301更接近1206，因此用前者填充
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1206    S_1   C_2      F  street_6     167      63  68.4      B-
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %% [markdown]
# ### reindex_like的作用为生成一个横纵索引完全与参数列表一致的DataFrame，数据使用被调用的表

# %%
df_temp = pd.DataFrame({'Weight':np.random.rand(5),#zeros(5),
                        'Height':np.random.rand(5),
                        'ID':[1101,1104,1103,1106,1102]}).set_index('ID')
df_temp.reindex_like(df[0:5][['Weight','Height']])
# Out:
#         Weight    Height
# ID
# 1101  0.233721  0.788896
# 1102  0.268108  0.006680
# 1103  0.314596  0.086971
# 1104  0.721702  0.241938
# 1105       NaN       NaN

# %%
df_temp
# Out:
#         Weight    Height
# ID
# 1101  0.233721  0.788896
# 1104  0.721702  0.241938
# 1103  0.314596  0.086971
# 1106  0.801879  0.811392
# 1102  0.268108  0.006680

# %%
df_temp.reset_index()
# Out:
#      ID    Weight    Height
# 0  1101  0.233721  0.788896
# 1  1104  0.721702  0.241938
# 2  1103  0.314596  0.086971
# 3  1106  0.801879  0.811392
# 4  1102  0.268108  0.006680

# %% [markdown]
# #### 如果df_temp单调还可以使用method参数：

# %%
df_temp = pd.DataFrame({'Weight':range(5),
                        'Height':range(5),
                        'ID':[1101,1104,1103,1106,1102]}).set_index('ID').sort_index()
df_temp.reindex_like(df[0:5][['Weight','Height']],method='bfill')
#可以自行检验这里的1105的值是否是由bfill规则填充
# Out:
#       Weight  Height
# ID
# 1101       0       0
# 1102       4       4
# 1103       2       2
# 1104       1       1
# 1105       3       3

# %% [markdown]
# ## 3.3. set_index和reset_index
# ### 3.3.1 set_index：从字面意思看，就是将某些列作为索引

# %% [markdown]
# #### 3.3.1.1 使用表内列作为索引：

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.set_index('Class').head()
# Out:
#       School Gender   Address  Height  Weight  Math Physics
# Class
# C_1      S_1      M  street_1     173      63  34.0      A+
# C_1      S_1      F  street_2     192      73  32.5      B+
# C_1      S_1      M  street_2     186      82  87.2      B+
# C_1      S_1      F  street_2     167      81  80.4      B-
# C_1      S_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 3.3.1.2 利用append参数可以将当前索引维持不变

# %%
df.set_index('Class',append=True).head()
# Out:
#            School Gender   Address  Height  Weight  Math Physics
# ID   Class
# 1101 C_1      S_1      M  street_1     173      63  34.0      A+
# 1102 C_1      S_1      F  street_2     192      73  32.5      B+
# 1103 C_1      S_1      M  street_2     186      82  87.2      B+
# 1104 C_1      S_1      F  street_2     167      81  80.4      B-
# 1105 C_1      S_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 3.3.1.3 当使用与表长相同的列作为索引（需要先转化为Series，否则报错）：

# %%
df.set_index(pd.Series(range(df.shape[0]))).head()
# Out:
#   School Class Gender   Address  Height  Weight  Math Physics
# 0    S_1   C_1      M  street_1     173      63  34.0      A+
# 1    S_1   C_1      F  street_2     192      73  32.5      B+
# 2    S_1   C_1      M  street_2     186      82  87.2      B+
# 3    S_1   C_1      F  street_2     167      81  80.4      B-
# 4    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 3.3.1.4 可以直接添加多级索引：

# %%
df.set_index([pd.Series(range(df.shape[0])),pd.Series(np.ones(df.shape[0]))]).head()
# Out:
#       School Class Gender   Address  Height  Weight  Math Physics
# 0 1.0    S_1   C_1      M  street_1     173      63  34.0      A+
# 1 1.0    S_1   C_1      F  street_2     192      73  32.5      B+
# 2 1.0    S_1   C_1      M  street_2     186      82  87.2      B+
# 3 1.0    S_1   C_1      F  street_2     167      81  80.4      B-
# 4 1.0    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# ### 3.3.2 reset_index方法，它的主要功能是将索引重置
# #### 3.3.2.1 默认状态直接恢复到自然数索引：

# %%
df.reset_index().head()
# Out:
#      ID School Class Gender   Address  Height  Weight  Math Physics
# 0  1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1  1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 2  1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 3  1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 4  1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### 3.3.2.2 用level参数指定哪一层被reset，用col_level参数指定set到哪一层：

# %%
L1,L2 = ['A','B','C'],['a','b','c']
mul_index1 = pd.MultiIndex.from_product([L1,L2],names=('Upper', 'Lower'))
L3,L4 = ['D','E','F'],['d','e','f']
mul_index2 = pd.MultiIndex.from_product([L3,L4],names=('Big', 'Small'))
df_temp = pd.DataFrame(np.random.rand(9,9),index=mul_index1,columns=mul_index2)
df_temp.head()
# Out:
# Big                 D                             E                      \
# Small               d         e         f         d         e         f
# Upper Lower
# A     a      0.155169  0.928454  0.111694  0.611897  0.809286  0.104764
#       b      0.428815  0.865397  0.062177  0.157647  0.788562  0.448264
#       c      0.638895  0.160121  0.253496  0.806406  0.823644  0.666344
# B     a      0.731386  0.021787  0.194566  0.361321  0.663231  0.918904
#       b      0.717433  0.634780  0.566621  0.449492  0.674909  0.275615
#
# Big                 F
# Small               d         e         f
# Upper Lower
# A     a      0.805494  0.657463  0.226936
#       b      0.292929  0.822218  0.664445
#       c      0.556058  0.880700  0.700683
# B     a      0.184364  0.406647  0.938517
#       b      0.575472  0.470114  0.988462

# %%
df_temp1 = df_temp.reset_index(level=1,col_level=1)
df_temp1.head()
# Out:
# Big                 D                             E                      \
# Small Lower         d         e         f         d         e         f
# Upper
# A         a  0.155169  0.928454  0.111694  0.611897  0.809286  0.104764
# A         b  0.428815  0.865397  0.062177  0.157647  0.788562  0.448264
# A         c  0.638895  0.160121  0.253496  0.806406  0.823644  0.666344
# B         a  0.731386  0.021787  0.194566  0.361321  0.663231  0.918904
# B         b  0.717433  0.634780  0.566621  0.449492  0.674909  0.275615
#
# Big           F
# Small         d         e         f
# Upper
# A      0.805494  0.657463  0.226936
# A      0.292929  0.822218  0.664445
# A      0.556058  0.880700  0.700683
# B      0.184364  0.406647  0.938517
# B      0.575472  0.470114  0.988462

# %%
df_temp1.columns
#看到的确插入了level2
# Out:
# MultiIndex([( '', 'Lower'),
#             ('D',     'd'),
#             ('D',     'e'),
#             ('D',     'f'),
#             ('E',     'd'),
#             ('E',     'e'),
#             ('E',     'f'),
#             ('F',     'd'),
#             ('F',     'e'),
#             ('F',     'f')],
#            names=['Big', 'Small'])

# %%
df_temp1.index
#最内层索引被移出
# Out:
# Index(['A', 'A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'], dtype='object', name='Upper')

# %% [markdown]
# ## 3.4. rename_axis和rename
# ### 3.4.1 rename_axis是针对多级索引的方法，作用是修改某一层的索引名，而不是索引标签

# %%
df_temp.rename_axis(index={'Lower':'LowerLower'},columns={'Big':'BigBig'})
# Out:
# BigBig                   D                             E                      \
# Small                    d         e         f         d         e         f
# Upper LowerLower
# A     a           0.155169  0.928454  0.111694  0.611897  0.809286  0.104764
#       b           0.428815  0.865397  0.062177  0.157647  0.788562  0.448264
#       c           0.638895  0.160121  0.253496  0.806406  0.823644  0.666344
# B     a           0.731386  0.021787  0.194566  0.361321  0.663231  0.918904
#       b           0.717433  0.634780  0.566621  0.449492  0.674909  0.275615
#       c           0.265503  0.802058  0.133690  0.442821  0.925366  0.805138
# C     a           0.666617  0.054462  0.780658  0.191979  0.983754  0.934848
#       b           0.214696  0.571703  0.867681  0.997084  0.708003  0.091064
#       c           0.335716  0.326930  0.003679  0.960601  0.359791  0.425822
#
# BigBig                   F
# Small                    d         e         f
# Upper LowerLower
# ...

# %% [markdown]
# ### 3.4.2 rename方法用于修改列或者行索引标签，而不是索引名：

# %%
df_temp.rename(index={'A':'T'},columns={'e':'changed_e'}).head()
# Out:
# Big                 D                             E                      \
# Small               d changed_e         f         d changed_e         f
# Upper Lower
# T     a      0.155169  0.928454  0.111694  0.611897  0.809286  0.104764
#       b      0.428815  0.865397  0.062177  0.157647  0.788562  0.448264
#       c      0.638895  0.160121  0.253496  0.806406  0.823644  0.666344
# B     a      0.731386  0.021787  0.194566  0.361321  0.663231  0.918904
#       b      0.717433  0.634780  0.566621  0.449492  0.674909  0.275615
#
# Big                 F
# Small               d changed_e         f
# Upper Lower
# T     a      0.805494  0.657463  0.226936
#       b      0.292929  0.822218  0.664445
#       c      0.556058  0.880700  0.700683
# B     a      0.184364  0.406647  0.938517
#       b      0.575472  0.470114  0.988462

# %% [markdown]
# # 四、常用索引型函数
# ## 4.1. where函数
# ### 4.1.1 当对条件为False的单元进行填充：

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %%
df.where(df['Gender']=='M').head()
#不满足条件的行全部被设置为NaN
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1102    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 1103    S_1   C_1      M  street_2   186.0    82.0  87.2      B+
# 1104    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN
# 1105    NaN   NaN    NaN       NaN     NaN     NaN   NaN     NaN

# %% [markdown]
# #### 通过这种方法筛选结果和[]操作符的结果完全一致：

# %%
df.where(df['Gender']=='M').dropna().head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1   173.0    63.0  34.0      A+
# 1103    S_1   C_1      M  street_2   186.0    82.0  87.2      B+
# 1201    S_1   C_2      M  street_5   188.0    68.0  97.0      A-
# 1203    S_1   C_2      M  street_6   160.0    53.0  58.8      A+
# 1301    S_1   C_3      M  street_4   161.0    68.0  31.5      B+

# %% [markdown]
# #### 第一个参数为布尔条件，第二个参数为填充值：

# %%
df.where(df['Gender']=='M',np.random.rand(df.shape[0],df.shape[1])).head()
# Out:
#         School     Class    Gender   Address      Height     Weight  \
# ID
# 1101       S_1       C_1         M  street_1  173.000000  63.000000
# 1102  0.711996  0.450499  0.936205  0.212271    0.314872   0.436034
# 1103       S_1       C_1         M  street_2  186.000000  82.000000
# 1104  0.112989  0.403086  0.862547  0.735754    0.726494   0.944321
# 1105  0.632738  0.175875  0.571131  0.524213    0.873143   0.600653
#
#            Math   Physics
# ID
# 1101  34.000000        A+
# 1102   0.115314  0.633871
# 1103  87.200000        B+
# 1104   0.405782  0.930299
# 1105   0.128453  0.820604

# %% [markdown]
# ## 4.2. mask函数
# ### mask函数与where功能上相反，其余完全一致，即对条件为True的单元进行填充

# %%
df.mask(df['Gender']=='M').dropna().head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1102    S_1   C_1      F  street_2   192.0    73.0  32.5      B+
# 1104    S_1   C_1      F  street_2   167.0    81.0  80.4      B-
# 1105    S_1   C_1      F  street_4   159.0    64.0  84.8      B+
# 1202    S_1   C_2      F  street_4   176.0    94.0  63.5      B-
# 1204    S_1   C_2      F  street_5   162.0    63.0  33.8       B

# %%
df.mask(df['Gender']=='M',np.random.rand(df.shape[0],df.shape[1])).head()
# Out:
#         School     Class    Gender   Address      Height     Weight  \
# ID
# 1101  0.110018  0.300278  0.426082  0.018607    0.634953   0.349136
# 1102       S_1       C_1         F  street_2  192.000000  73.000000
# 1103  0.249456  0.520518  0.012142  0.568434    0.431986   0.697362
# 1104       S_1       C_1         F  street_2  167.000000  81.000000
# 1105       S_1       C_1         F  street_4  159.000000  64.000000
#
#            Math   Physics
# ID
# 1101   0.690750  0.451417
# 1102  32.500000        B+
# 1103   0.515329  0.433738
# 1104  80.400000        B-
# 1105  84.800000        B+

# %% [markdown]
# ## 4.3. query函数

# %%
df.head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+

# %% [markdown]
# #### query函数中的布尔表达式中，下面的符号都是合法的：行列索引名、字符串、and/not/or/&/|/~/not in/in/==/!=、四则运算符

# %%
df.query('(Address in ["street_6","street_7"])&(Weight>(70+10))&(ID in [1303,2304,2402])')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1303    S_1   C_3      M  street_7     188      82  49.7       B
# 2304    S_2   C_3      F  street_6     164      81  95.5      A-
# 2402    S_2   C_4      M  street_7     166      82  48.7       B

# %% [markdown]
# # 五、重复元素处理
# ## 5.1. duplicated方法
# #### 该方法返回了是否重复的布尔列表

# %%
df.duplicated('Class').head()
# Out:
# ID
# 1101    False
# 1102     True
# 1103     True
# 1104     True
# 1105     True
# dtype: bool

# %% [markdown]
# #### 可选参数keep默认为first，即首次出现设为不重复，若为last，则最后一次设为不重复，若为False，则所有重复项为True

# %%
df.duplicated('Class',keep=False).head()
# Out:
# ID
# 1101    True
# 1102    True
# 1103    True
# 1104    True
# 1105    True
# dtype: bool

# %% [markdown]
# ## 5.2. drop_duplicates方法
# #### 从名字上看出为剔除重复项，这在后面章节中的分组操作中可能是有用的，例如需要保留每组的第一个值：

# %%
df.drop_duplicates('Class')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 2401    S_2   C_4      F  street_2     192      62  45.3       A

# %% [markdown]
# #### 参数与duplicate函数类似：

# %%
df.drop_duplicates('Class',keep='last')
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 2105    S_2   C_1      M  street_4     170      81  34.2       A
# 2205    S_2   C_2      F  street_7     183      76  85.4       B
# 2305    S_2   C_3      M  street_4     187      73  48.9       B
# 2405    S_2   C_4      F  street_6     193      54  47.6       B

# %% [markdown]
# #### 在传入多列时等价于将多列共同视作一个多级索引，比较重复项：

# %%
df.drop_duplicates(['School','Class'])
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1101    S_1   C_1      M  street_1     173      63  34.0      A+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 2101    S_2   C_1      M  street_7     174      84  83.3       C
# 2201    S_2   C_2      M  street_5     193     100  39.1       B
# 2301    S_2   C_3      F  street_4     157      78  72.3      B+
# 2401    S_2   C_4      F  street_2     192      62  45.3       A

# %% [markdown]
# # 六、抽样函数
# #### 这里的抽样函数指的就是sample函数
# ## 6.1（a）n为样本量

# %%
df.sample(n=5)
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1301    S_1   C_3      M  street_4     161      68  31.5      B+
# 1103    S_1   C_1      M  street_2     186      82  87.2      B+
# 2301    S_2   C_3      F  street_4     157      78  72.3      B+
# 2103    S_2   C_1      M  street_4     157      61  52.5      B-
# 2104    S_2   C_1      F  street_5     159      97  72.2      B+

# %% [markdown]
# ## 6.2（b）frac为抽样比

# %%
df.sample(frac=0.05)
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1204    S_1   C_2      F  street_5     162      63  33.8       B

# %% [markdown]
# ## 6.3（c）replace为是否放回

# %%
df.sample(n=df.shape[0],replace=True).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1302    S_1   C_3      F  street_1     175      57  87.7      A-
# 1203    S_1   C_2      M  street_6     160      53  58.8      A+
# 1201    S_1   C_2      M  street_5     188      68  97.0      A-
# 1105    S_1   C_1      F  street_4     159      64  84.8      B+
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-

# %%
df.sample(n=35,replace=True).index.is_unique
# Out:
# False

# %% [markdown]
# ## 6.4（d）axis为抽样维度，默认为0，即抽行

# %%
df.sample(n=3,axis=1).head()
# Out:
#      Gender  Math   Address
# ID
# 1101      M  34.0  street_1
# 1102      F  32.5  street_2
# 1103      M  87.2  street_2
# 1104      F  80.4  street_2
# 1105      F  84.8  street_4

# %% [markdown]
# ## 6.5（e）weights为样本权重，自动归一化

# %%
df.sample(n=3,weights=np.random.rand(df.shape[0])).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1202    S_1   C_2      F  street_4     176      94  63.5      B-
# 1102    S_1   C_1      F  street_2     192      73  32.5      B+

# %%
#以某一列为权重，这在抽样理论中很常见
#抽到的概率与Math数值成正比
df.sample(n=3,weights=df['Math']).head()
# Out:
#      School Class Gender   Address  Height  Weight  Math Physics
# ID
# 1104    S_1   C_1      F  street_2     167      81  80.4      B-
# 1205    S_1   C_2      F  street_6     167      63  68.4      B-
# 2305    S_2   C_3      M  street_4     187      73  48.9       B

# %% [markdown]
# # 七、问题与练习

# %% [markdown]
# ## 7.1. 问题
# ### 7.1.1 【问题一】 如何更改列或行的顺序？如何交换奇偶行（列）的顺序？
# ### 7.1.2 【问题二】 如果要选出DataFrame的某个子集，请给出尽可能多的方法实现。
# ### 7.1.3 【问题三】 query函数比其他索引方法的速度更慢吗？在什么场合使用什么索引最高效？
# ### 7.1.4 【问题四】 单级索引能使用Slice对象吗？能的话怎么使用，请给出一个例子。
# ### 7.1.5 【问题五】 如何快速找出某一列的缺失值所在索引？
# ### 7.1.6 【问题六】 索引设定中的所有方法分别适用于哪些场合？怎么直接把某个DataFrame的索引换成任意给定同长度的索引？
# ### 7.1.7 【问题七】 对于多层索引，怎么对内层进行条件筛选？
# ### 7.1.8 【问题八】 swaplevel中的axis参数为1时，代表什么意思？i和j只能是数值型吗？

# %% [markdown]
# ## 7.2. 练习
# ### 7.2.1【练习一】 现有一份关于UFO的数据集，请解决下列问题：

# %%
pd.read_csv('data/UFO.csv').head()
# Out:
#            datetime     shape  duration (seconds)   latitude   longitude
# 0  10/10/1949 20:30  cylinder              2700.0  29.883056  -97.941111
# 1  10/10/1949 21:00     light              7200.0  29.384210  -98.581082
# 2  10/10/1955 17:00    circle                20.0  53.200000   -2.916667
# 3  10/10/1956 21:00    circle                20.0  28.978333  -96.645833
# 4  10/10/1960 20:00     light               900.0  21.418056 -157.803611

# %% [markdown]
# ### 7.2.2（a）在所有被观测时间超过60s的时间中，哪个形状最多？

# %%
df = pd.read_csv('data/UFO.csv')
df.rename(columns={'duration (seconds)':'duration'},inplace=True)
df['duration'].astype('float')
df.head()
# Out:
#            datetime     shape  duration   latitude   longitude
# 0  10/10/1949 20:30  cylinder    2700.0  29.883056  -97.941111
# 1  10/10/1949 21:00     light    7200.0  29.384210  -98.581082
# 2  10/10/1955 17:00    circle      20.0  53.200000   -2.916667
# 3  10/10/1956 21:00    circle      20.0  28.978333  -96.645833
# 4  10/10/1960 20:00     light     900.0  21.418056 -157.803611

# %%
df.query('duration > 60')['shape'].value_counts().index[0]
# Out:
# 'light'

# %% [markdown]
# ### 7.2.3（b）对经纬度进行划分：-180°至180°以30°为一个经度划分，-90°至90°以18°为一个维度划分，请问哪个区域中报告的UFO事件数量最多？

# %%
bins_long = np.linspace(-180,180,13).tolist()
bins_la = np.linspace(-90,90,11).tolist()
cuts_long = pd.cut(df['longitude'],bins=bins_long)
df['cuts_long'] = cuts_long
cuts_la = pd.cut(df['latitude'],bins=bins_la)
df['cuts_la'] = cuts_la
df.head()
# Out:
#            datetime     shape  duration   latitude   longitude  \
# 0  10/10/1949 20:30  cylinder    2700.0  29.883056  -97.941111
# 1  10/10/1949 21:00     light    7200.0  29.384210  -98.581082
# 2  10/10/1955 17:00    circle      20.0  53.200000   -2.916667
# 3  10/10/1956 21:00    circle      20.0  28.978333  -96.645833
# 4  10/10/1960 20:00     light     900.0  21.418056 -157.803611
#
#           cuts_long       cuts_la
# 0   (-120.0, -90.0]  (18.0, 36.0]
# 1   (-120.0, -90.0]  (18.0, 36.0]
# 2      (-30.0, 0.0]  (36.0, 54.0]
# 3   (-120.0, -90.0]  (18.0, 36.0]
# 4  (-180.0, -150.0]  (18.0, 36.0]

# %%
df.set_index(['cuts_long','cuts_la']).index.value_counts().head()
# Out:
# ((-90.0, -60.0], (36.0, 54.0])      27891
# ((-120.0, -90.0], (18.0, 36.0])     14280
# ((-120.0, -90.0], (36.0, 54.0])     11960
# ((-90.0, -60.0], (18.0, 36.0])       9923
# ((-150.0, -120.0], (36.0, 54.0])     9658
# dtype: int64

# %% [markdown]
# ### 7.2.2 【练习二】 现有一份关于口袋妖怪的数据集，请解决下列问题：

# %%
pd.read_csv('data/Pokemon.csv').head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df = pd.read_csv('data/Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# #### 7.2.2.1（a）双属性的Pokemon占总体比例的多少？

# %%
df['Type 2'].count()/df.shape[0]
# Out:
# 0.5175

# %% [markdown]
# #### 7.2.2.2（b）在所有种族值（Total）不小于580的Pokemon中，非神兽（Legendary=False）的比例为多少？

# %%
df.query('Total >= 580')['Legendary'].value_counts(normalize=True)
# Out:
# True     0.575221
# False    0.424779
# Name: Legendary, dtype: float64

# %% [markdown]
# #### 7.2.2.3（c）在第一属性为格斗系（Fighting）的Pokemon中，物攻排名前三高的是哪些？

# %%
df[df['Type 1']=='Fighting'].sort_values(by='Attack',ascending=False).iloc[:3]
# Out:
#        #                 Name    Type 1 Type 2  Total   HP  Attack  Defense  \
# 498  448  LucarioMega Lucario  Fighting  Steel    625   70     145       88
# 594  534           Conkeldurr  Fighting    NaN    505  105     140       95
# 74    68              Machamp  Fighting    NaN    505   90     130       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 498      140       70    112           4      False
# 594       55       65     45           5      False
# 74        65       85     55           1      False

# %% [markdown]
# 分别为Maga形态的路卡利欧、修缮老头、怪力

# %% [markdown]
# #### 7.2.2.4（d）请问六项种族指标（HP、物攻、特攻、物防、特防、速度）极差的均值最大的是哪个属性（只考虑第一属性，且均值是对属性而言）？

# %%
df['range'] = df.iloc[:,5:11].max(axis=1)-df.iloc[:,5:11].min(axis=1)
attribute = df[['Type 1','range']].set_index('Type 1')
max_range = 0
result = ''
for i in attribute.index.unique():
    temp = attribute.loc[i,:].mean()
    if temp.values[0] > max_range:
        max_range = temp.values[0]
        result = i
result
# Out:
# 'Steel'

# %% [markdown]
# 钢系的极差均值最大

# %% [markdown]
# #### 7.2.2.5（e）哪个属性（只考虑第一属性）神兽占总Pokemon的比例最高？该属性神兽的种族值也是最高的吗？

# %%
df.query('Legendary == True')['Type 1'].value_counts(normalize=True).index[0]
# Out:
# 'Psychic'

# %%
attribute = df.query('Legendary == True')[['Type 1','Total']].set_index('Type 1')
max_value = 0
result = ''
for i in attribute.index.unique():
    temp = float(attribute.loc[i,:].mean())
    if temp > max_value:
        max_value = temp
        result = i
result
# Out:
# 'Normal'
